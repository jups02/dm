# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.makedirs('/content/drive/MyDrive/DataMaster', exist_ok=True)

# %%
# !git clone https://github.com/jups02/dm.git /content/drive/MyDrive/DataMaster/
# Out:
# fatal: destination path '/content/drive/MyDrive/DataMaster' already exists and is not an empty directory.

# %%
# %cd /content/drive/MyDrive/DataMaster
# Out:
# /content/drive/MyDrive/DataMaster

# %%
# %cd /content/drive/MyDrive/DataMaster
# !ls
# Out:
# /content/drive/MyDrive/DataMaster
# explo.ipynb  README.md.gdoc

# %%
# !git clone https://github.com/jups02/dm.git /content/drive/MyDrive/DataMaster/dm
# Out:
# Cloning into '/content/drive/MyDrive/DataMaster/dm'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# !mv /content/drive/MyDrive/DataMaster/explo.ipynb /content/drive/MyDrive/DataMaster/dm/
# Out:
# mv: cannot stat '/content/drive/MyDrive/DataMaster/explo.ipynb': No such file or directory

# %% [markdown]
# a partir daqui

# %%
# %cd /content/drive/MyDrive/DataMaster/dm
# !ls
# Out:
# /content/drive/MyDrive/DataMaster/dm
#  case_dm_edas.ipynb	    df_validacao.parquet
# 'case dm v2.ipynb'	    exploratoria.ipynb
#  df_dm_join.parquet	    gitcommit.ipynb
#  df_oot.parquet		    members_filtered.parquet
#  df_target_sample.parquet   README.md
#  df_teste.parquet	    transactions_filtered.parquet
#  df_treino.parquet	    user_logs_filtered.parquet

# %%
# !git config --global user.name "jups02"
# !git config --global user.email "jups02@gmail.com"

# %%
# %cd /content/drive/MyDrive/DataMaster/dm
# Out:
# /content/drive/MyDrive/DataMaster/dm

# %%
# !git add .
# !git commit -m "atualizacao 05102025_2"
# !git push origin main

# %%
# %cd /content/drive/MyDrive/DataMaster/dm

# !git add explo.ipynb
# !git commit -m "update teste"

# %%
import getpass
token = getpass.getpass("Cole aqui seu token GitHub (ele ficará escondido): ")

# !git remote set-url origin https://jups02:{token}@github.com/jups02/dm.git
# !git push origin main

# %%
ls -lha
# Out:
# total 451K
# -rw------- 1 root root 401K Jul 27 23:53 case_dm.ipynb
# -rw------- 1 root root  37K Jul 13 19:37 exploratoria.ipynb
# drwx------ 7 root root 4.0K Jul 27 23:55 .git/
# -rw------- 1 root root 8.5K Jul 27 23:54 gitcommit.ipynb
# -rw------- 1 root root   54 Jul  1 23:43 README.md

# %%
# !ls "/content/drive/MyDrive/DataMaster/dm"
# Out:
# ls: cannot access '/content/drive/MyDrive/DataMaster/dm': No such file or directory
