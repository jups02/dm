# %% [markdown]
# # Importação dos dados

# %% [markdown]
# ## origem Kaggle - importação via kagglehub

# %%
import kagglehub

# baixar dados da pasta do data master
path = kagglehub.dataset_download("gcenachi/case-data-master-2024")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/case-data-master-2024

# %% [markdown]
# arquivos disponiveis no diretório kaggle

# %%
import os

# Ver tudo que foi baixado
print("Arquivos encontrados:")
for root, dirs, files in os.walk(path):
    for file in files:
        print(os.path.join(root, file))
# Out:
# Arquivos encontrados:
# /kaggle/input/case-data-master-2024/members.parquet
# /kaggle/input/case-data-master-2024/user_logs.parquet
# /kaggle/input/case-data-master-2024/transactions.parquet

# %%
import pandas as pd

path_base = "/root/.cache/kagglehub/datasets/gcenachi/case-data-master-2024/versions/1"

# %%
import pandas as pd
user_logs_sample = pd.read_parquet(f"{path_base}/user_logs.parquet", engine='pyarrow')
# user_logs_sample = user_logs_sample.sample(500_000)

# %%
user_logs_sample
# Out:
#                                                   msno   safra  num_25  \
# 0         SwlrSivYHoKF9V5wm1YYYAnjHpd9y3OPjI9rDUhGJ3k=  201701   121.0
# 1         rE5wSmHEF1Dhu55zhkiGB1HvotdlSHcIMGXv6VcqO2A=  201605    26.0
# 2         hx+cyaQ/Jcdr/Z5foa/Cn0PXUzC/F7QO/NQvWQS1Qtc=  201611   161.0
# 3         53QW6B70J23X2UCvxaaUppjyE0b6X9nzP79W4huZv+Q=  201502    37.0
# 4         /0S1N/oRyxGLZlzxnW5rOjfo0ZAls9EH23ahuDNuqz8=  201506   205.0
# ...                                                ...     ...     ...
# 26758966  k+pC7Jft9Xd/PUeJl78Ui5MX6jZ73jEfzJwZ2Dvhw2w=  201608     0.0
# 26758967  ong+wjn9kNXomYNrMsjqFOK1IOeRpvXk46Aooo3ZTy8=  201504     0.0
# 26758968  ovU/3GFJyA+AOQz2ktixWF9n6/QwDDhiR1suvH31SFM=  201502     3.0
# 26758969  w5yMJvQ2MEjCHI0Ceydqt/LlNAXawLK9rVGAJHfb0Nc=  201702     5.0
# 26758970  zIIx+8p332XlCCLo3oHHx9yOMOjEr2v0mx+vTCZ5ULI=  201505     4.0
#
#           num_50  num_75  num_985  num_100  num_unq  total_secs
# 0           28.0    14.0     29.0    704.0    827.0  184606.903
# 1            2.0     5.0      6.0    462.0    256.0  119439.485
# 2           71.0    49.0     34.0    668.0    891.0  204791.242
# 3            9.0     3.0      9.0    408.0    447.0  101186.041
# 4           49.0    23.0     21.0    225.0    489.0   69957.524
# ...          ...     ...      ...      ...      ...         ...
# 26758966     0.0     0.0      0.0      1.0      1.0     240.000
# 26758967     0.0     1.0      0.0      4.0      5.0    1227.269
# 26758968     0.0     0.0      0.0      1.0      4.0     267.960
# 26758969     0.0     1.0      0.0      3.0      8.0     969.863
# 26758970     3.0     3.0      0.0      1.0     10.0    1012.915
#
# [26758971 rows x 9 columns]

# %%
transactions_sample = pd.read_parquet(f"{path_base}/transactions.parquet", engine='pyarrow')
transactions_sample = transactions_sample.sample(500_000)

# %%
transactions_sample
# Out:
#                                                   msno payment_method_id  \
# 12515238  Ez+SfyffdXVa4is7m5m7+mQIRYJFynOA6rj+jYVxcLQ=                40
# 8290842   QFPvZdWjVxoerCHmr+8yOLO69W1rPJbwTe3WahCJRjQ=                40
# 264921    LIans8B0uUG5ailS9sh3DnR9mM9BSdHu3+F1yRWCBEA=                40
# 9560167   AHKhIBm+2Vzju3+YsnTWtMY80I96fwweuvWYm8ON+9w=                41
# 7750002   gV+yAzzZukEt1c3D95yX/duHErh0ZjS4R+amVWQAVVQ=                39
# ...                                                ...               ...
# 16079291  9mj/TNiEt4/esRgMU3YxHAmmJAuni7KmqHUU9Qs47Yc=                41
# 1503349   2fenU9Vn1G52QpcUPzM2bW6+dgU6TJtbldM5izmLAyY=                41
# 8400149   ZxVRLIcqO5gSLXfziKrmowExAxT1sU+llIPF3IFWM0w=                14
# 18883765  1IYtW9M7I0jq99T+UjcfrnGQSHoFoE4usBTblUbE+R4=                34
# 2064508   qIjBmkXJvjj/set9lNZ54Zj5uLMOEdvNvN5Kbxu5ebg=                34
#
#          payment_plan_days plan_list_price actual_amount_paid is_auto_renew  \
# 12515238                30             149                149             1
# 8290842                 31             149                149             1
# 264921                  30             149                149             1
# 9560167                 30              99                 99             1
# 7750002                 30             149                149             1
# ...                    ...             ...                ...           ...
# 16079291                30             149                149             1
# 1503349                 30             149                149             1
# 8400149                 30             149                149             1
# 18883765                 0               0                149             1
# 2064508                 30             149                149             1
#
#          transaction_date membership_expire_date is_cancel   safra
# 12515238         20170203               20170302         0  201702
# 8290842          20150118               20150218         0  201501
# 264921           20160619               20160720         0  201606
# 9560167          20160831               20161001         0  201608
# 7750002          20150930               20151108         0  201509
# ...                   ...                    ...       ...     ...
# 16079291         20150811               20150811         1  201508
# 1503349          20170217               20170317         0  201702
# 8400149          20160229               20160331         0  201602
# 18883765         20150831               20150930         0  201508
# 2064508          20160930               20161031         0  201609
#
# [500000 rows x 10 columns]

# %%
members_sample = pd.read_parquet(f"{path_base}/members.parquet", engine='pyarrow')
members_sample = members_sample.sample(100_000)
members_sample

# %% [markdown]
# Objetivo da EDA (para churn)
# Entender:
#
# Como os clientes se comportam antes de churnar
#
# Diferenças entre churners e não churners
#
# Quais variáveis parecem prever o cancelamento
#
# Distribuições, outliers, tendências temporais, etc.
